# %%
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
    
import matplotlib.pyplot as plt

# %%
text = "The choice was red, green, or blue. It didn't seem like an important choice when he was making it, but it was a choice nonetheless. Had he known the consequences at that time, he would likely have considered the choice a bit longer. In the end, he didn't and ended up choosing blue."
url = r"https://en.wikipedia.org/wiki/James_Longstreet"

# %%
# page = urlopen(url)

import requests
res = requests.get(url)
html_page = res.content

soup = BeautifulSoup(html_page, 'html.parser')
text = soup.text.replace("\n", "")

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10)

wc = wordcloud.generate(text)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# %%
import wikipediaapi

# %%
serach_word = "Python"

# %%
wiki_wiki = wikipediaapi.Wikipedia('en')
page_py = wiki_wiki.page(serach_word)

page_py

page_py.langlinks["ja"].summary
# Out:
# 'パイソン (Python)\n\n神話上、もしくは現実の大蛇の呼称。うわばみ。\nギリシア神話の蛇神、ピュトンの英語読み。\n爬虫綱有鱗目ニシキヘビ科に属する構成種に対しての英名。もしくはニシキヘビ属の属名。\n上記の大蛇にちなんで命名された呼称。\nモンティ・パイソン - イギリスのコメディユニット。\n空飛ぶモンティ・パイソン - モンティ・パイソンの出演するBBCのコメディ番組。\nPython - スクリプト言語。上記コメディ番組にちなむ。\nコルト・パイソン - 回転式拳銃。\nパイソン (ミサイル)\nMPL-97 パイソン - アニメ『機動警察パトレイバー』に登場するロボット。⇒機動警察パトレイバーの登場メカ#パイソン。'

# %%
list(page_py.links.keys())
# Out:
# ['CMU Common Lisp',
#  'Colt Python',
#  'Cython',
#  'Monty Python',
#  'PERQ',
#  'PYTHON',
#  'Pithon',
#  'Python (Busch Gardens Tampa Bay)',
#  'Python (Coney Island, Cincinnati, Ohio)',
#  'Python (Efteling)',
#  'Python (Ford prototype)',
#  'Python (Monty) Pictures',
#  'Python (automobile maker)',
#  'Python (film)',
#  'Python (genus)',
#  'Python (missile)',
#  'Python (mythology)',
#  'Python (nuclear primary)',
#  'Python (painter)',
#  'Python (programming language)',
#  'Python Anghelo',
#  'Python of Aenus',
#  'Python of Byzantium',
#  'Python of Catana',
#  'Pythonidae',
#  'Pyton',
#  'Talk:Python',
#  'Help:Disambiguation']

# %%
try_wiki_wiki = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI
)

p_wiki = wiki_wiki.page("Tornado outbreak of December 10–11, 2021")



# print(p_wiki.links)

summary = p_wiki.summary


def list_sections(sections, ):

for idx, section in enumerate(p_wiki.sections):
        print(f"*\t{section.title}")
        for sub_sec in section.sections:
                print(f"**\t{sub_sec.title}")
                for subsub_sec in sub_sec.sections:
                        print(subsub_sec)
# Out:
# *	Meteorological synopsis
# *	Confirmed tornadoes
# **	December 10 event
# **	December 11 event
# *	Impact
# **	Arkansas
# **	Illinois
# **	Kentucky
# **	Missouri
# **	Tennessee
# *	Non-tornadic impacts
# *	Aftermath
# *	See also
# *	Notes

# %%
p_wiki.sections[1].sections[0]
# Out:
# Section: December 10 event (2):
#
# Subsections (0):

# %%
p_wiki.langlinks["ja"].summary
# Out:
# '2021年12月のアメリカ合衆国の竜巻（2021ねん12がつのあめりかがっしゅうこくのたつまき）では、 2021年12月10日から12月11日にかけて、アメリカ合衆国で多発した一連の竜巻とそれによる災害について述べる。'

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10)

wc = wordcloud.generate(summary)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)

# %%
import pywikibot
from pywikibot import pagegenerators
site = pywikibot.Site()
cat = pywikibot.Category(site,'Category:Living people')
gen = pagegenerators.CategorizedPageGenerator(cat)
for page in gen:
    #Do something with the page object, for example:
    text = page.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15860/3519986096.py in <module>
#       1 import pywikibot
#       2 from pywikibot import pagegenerators
# ----> 3 site = pywikibot.Site()
#       4 cat = pywikibot.Category(site,'Category:Living people')
#       5 gen = pagegenerators.CategorizedPageGenerator(cat)
#
# d:\Python\git\.venv\lib\site-packages\pywikibot\tools\_deprecate.py in wrapper(*__args, **__kw)
#     402                 del __kw[old_arg]
#     403
# --> 404             return obj(*__args, **__kw)
#     405
#     406         if not __debug__:
#
# d:\Python\git\.venv\lib\site-packages\pywikibot\__init__.py in Site(code, fam, user, interface, url)
#    1233     key = '{}:{}:{}:{}'.format(interface.__name__, fam, code, user)
#    1234     if key not in _sites or not isinstance(_sites[key], interface):
# ...
